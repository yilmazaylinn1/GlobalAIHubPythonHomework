# %%
count = 0

Name = "Aylin"
Surname = "Yilmaz"

check = False

print('You have 3 attempts to enter your Name and Surname!')
while count < 3:
    Name1 = input("Please enter your name: ")
    Surname1 = input("Please enter your surname: ")

    count = count + 1
    if Name1 == Name and Surname1 == Surname:
        break

    if Name1 == Name or Surname1 == Surname:
        print(" Please Try again !")

    elif Name1 != Name or Surname1 != Surname:
        print(" Please Try again !")

if Name1 == Name and Surname1 == Surname:
    print("\nWelcome " + Name +" " + Surname)

if name1 != Name and Surname1 != Surname:
    print("Please Try again later!")

courses = []
for lesson in courses:
    print(courses)
print("Enter 5 courses Name")
for i in range(5):
    course = input("\nPlease Enter The Course Name: ")
    courses.append(course.capitalize())
print(courses)


def selectin_course():
    n = int(input("\nEnter the Number of Courses You Will take: "))
    if n<3:
        return print("You Failed!!")
    elif 3 <= n < 5:
        selected_course = [input("\nEnter The Course Name: ") for i in range(n)]
        return print(selected_course)
    else:
        print("Invalid Choice..")

selectin_course()

Python = {"Midterm":60, "Final":66, "Project":54}
Java = {"Midterm":30, "Final":80, "Project":46}
R_Programming = {"Midterm":95, "Final":80, "Project":100}
C_Programming = {"Midterm":45, "Final":75, "Project":90}
Data_Science = {"Midterm":73, "Final":55, "Project":68}


Student_Courses = [Python, Java, R_Programming, C_Programming, Data_Science]


def Get_Average(Student_Courses):
    Midterm = Student_Courses["Midterm"]
    Final = Student_Courses["Final"]
    Project = Student_Courses["Project"]
    return (0.3*Midterm + 0.2*Project + 0.5*Final)

def Assign_Letter(Grade):
    if Grade >= 90:
        return "AA"
    elif 70 < Grade < 90:
        return "BB"
    elif 50 < Grade < 70:
        return "CC"
    elif 30 < Grade < 50:
        print("You failed!")
        return "FF"

ch = input("\nChoose One Course From  the List: ")
ch = ch.capitalize()
if ch == "Python":
    Python = {"Midterm":60, "Final":66, "Project":54}
    print("Grade of Python is: ", Get_Average(Python))
    print("Letter grade of Python is:  ", Assign_Letter(Get_Average(Python)))
elif ch == "Java":
    Java = {"Midterm":30, "Final":80, "Project":46}
    print("Grade of Java is:  " , Get_Average(Java))
    print("Letter grade of Java is:  " ,  Assign_Letter(Get_Average(Java)))
elif ch == "R_Programming":
    R_Programming = {"Midterm":95, "Final":80, "Project":100}
    print("Grade of R_Programming is: " , Get_Average(R_Programming))
    print("Letter grade of R_Programming is: ", Assign_Letter(Get_Average(R_Programming)))
elif ch == "C_Programming":
    C_Programming = {"Midterm":45, "Final":75, "Project":90}
    print("Grade of C_Programming is: " , Get_Average(C_Programming))
    print("Letter grade of C_Programming is: ", Assign_Letter(Get_Average(C_Programming)))
elif ch == "Data_Science":
    Data_Science = {"Midterm":73, "Final":65, "Project":68}
    print("Grade of Data_Science is: " , Get_Average(Data_Science))
    print("Letter grade of Data_Science is: ", Assign_Letter(Get_Average(Data_Science)))
else:
    print("Invalid Course..")
# Out:
# You have 3 attempts to enter your Name and Surname!
# Please enter your name: Aylin
# Please enter your surname: Yilmaz
#
# Welcome Aylin Yilmaz
# Enter 5 courses Name
#
# Please Enter The Course Name: Python
#
# Please Enter The Course Name: Java
#
# Please Enter The Course Name: R_Programming
#
# Please Enter The Course Name: C_Programming
#
# Please Enter The Course Name: Data_Science
# ['Python', 'Java', 'R_programming', 'C_programming', 'Data_science']
#
# Enter the Number of Courses You Will take: 4
#
# Enter The Course Name: Python
#
# Enter The Course Name: Java
#
# Enter The Course Name: Data_Science
#
# Enter The Course Name: R_Programming
# ['Python', 'Java', 'Data_Science', 'R_Programming']
#
# Choose One Course From  the List: Python
# Grade of Python is:  61.8
# Letter grade of Python is:   CC
